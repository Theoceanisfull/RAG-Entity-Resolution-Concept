# %%
# Install the missing package
#%pip install sentence-transformers

import pandas as pd 
from sentence_transformers import SentenceTransformer

from sklearn.cluster import AgglomerativeClustering
import numpy as np

# %%
ar_dj = pd.read_csv('Synthetic_Aaron_Rodgers_Entity_Mentions.csv')
ar_dj['entity'] = 'Aaron Rodgers'
mj_df = pd.read_csv('Synthetic_Michael_Jordan_Entity_Mentions.csv')
mj_df['entity'] = 'Michael Jordan'
sj_df = pd.read_csv('Synthetic_Steve_Jobs_Entity_Mentions.csv')
sj_df['entity'] = 'Steve Jobs' 
vp_pd = pd.read_csv('Synthetic_Vladimir_Putin_Entity_Mentions.csv')
vp_pd['entity'] = 'Vladimir Putin'
cp_df = pd.read_csv('Synthetic_Chinese_Business_Enterprise_Mentions.csv')
ol_df = pd.read_csv('Synthetic_Osama_Bin_Laden_Entity_Mentions.csv')
ad_df = pd.read_csv('Synthetic_Arms_Dealer_Entity_Mentions.csv')
cb_df = pd.read_csv('Synthetic_Chinese_Business_Enterprise_Mentions.csv')
tw_df = pd.read_csv('Synthetic_Tiger_Woods_Entity_Mentions.csv')
re_df = pd.read_csv('Synthetic_Random_Entity_Mentions.csv')
ts_df =pd.read_csv('Synthetic_Taylor_Swift_Entity_Mentions.csv')
df = pd.concat([ar_dj, mj_df, sj_df, vp_pd, cp_df, ol_df, ad_df, cb_df, tw_df, re_df, ts_df], ignore_index=True)

# %% [markdown]
# Simple step by step pipeline

# %%
#Adds a dictionary of entity mentions to the dataframe in metadata
from langchain.schema import Document 

document = [Document(page_content=row['text'], metadata={'entity': row.to_dict()}) for _, row in df.iterrows()]

# %%
for doc in document:
    print(doc.metadata['entity'])
# Out:
# {'text': 'Mr. Rodgers was featured in a sports segment on Lambeau Field.', 'entity': 'Aaron Rodgers'}
# {'text': 'Aaron Rodgers participated in offseason training at Lambeau Field.', 'entity': 'Aaron Rodgers'}
# {'text': 'The Quarterback was featured in a sports segment on the Pat McAfee Show.', 'entity': 'Aaron Rodgers'}
# {'text': 'Green Bay QB hosted a charity event at ESPN.', 'entity': 'Aaron Rodgers'}
# {'text': 'Rodgers led a fourth-quarter comeback in a quarterback camp.', 'entity': 'Aaron Rodgers'}
# {'text': 'The Quarterback hosted a charity event at NFL Honors.', 'entity': 'Aaron Rodgers'}
# {'text': 'A. Rodgers was featured in a sports segment on the Pat McAfee Show.', 'entity': 'Aaron Rodgers'}
# {'text': 'AR12 gave an interview to NBC Sports.', 'entity': 'Aaron Rodgers'}
# {'text': 'Aaron Rodgers gave an interview to ESPN.', 'entity': 'Aaron Rodgers'}
# {'text': 'AR12 signed a new contract with ESPN.', 'entity': 'Aaron Rodgers'}
# {'text': 'Mr. Rodgers signed a new contract with ESPN.', 'entity': 'Aaron Rodgers'}
# {'text': 'The Quarterback hosted a charity event at CBS Sports.', 'entity': 'Aaron Rodgers'}
# {'text': 'The Quarterback was featured in a sports segment on CBS Sports.', 'entity': 'Aaron Rodgers'}
# {'text': 'Rodgers announced his future plans during NFL Honors.', 'entity': 'Aaron Rodgers'}
# {'text': 'Mr. Rodgers attended a team strategy meeting at a quarterback camp.', 'entity': 'Aaron Rodgers'}
# {'text': 'AR12 was featured in a sports segment on NBC Sports.', 'entity': 'Aaron Rodgers'}
# {'text': 'Green Bay QB was traded to a new team during NFL Honors.', 'entity': 'Aaron Rodgers'}
# {'text': 'Number 12 gave an interview to a local Wisconsin fundraiser.', 'entity': 'Aaron Rodgers'}
# {'text': 'Rodgers was traded to a new team during the Green Bay Packers.', 'entity': 'Aaron Rodgers'}
# {'text': 'NFL MVP spoke on a podcast about NFL Honors.', 'entity': 'Aaron Rodgers'}
# {'text': 'NFL MVP attended a team strategy meeting at Lambeau Field.', 'entity': 'Aaron Rodgers'}
# {'text': 'Green Bay QB participated in offseason training at CBS Sports.', 'entity': 'Aaron Rodgers'}
# {'text': 'The Quarterback led a fourth-quarter comeback in ESPN.', 'entity': 'Aaron Rodgers'}
# {'text': 'Rodgers signed a new contract with Lambeau Field.', 'entity': 'Aaron Rodgers'}
# {'text': 'A. Rodgers was traded to a new team during a quarterback camp.', 'entity': 'Aaron Rodgers'}
# {'text': 'Mr. Rodgers announced his future plans during NBC Sports.', 'entity': 'Aaron Rodgers'}
# {'text': 'A. Rodgers gave an interview to the Pat McAfee Show.', 'entity': 'Aaron Rodgers'}
# {'text': 'Aaron Rodgers led a fourth-quarter comeback in Lambeau Field.', 'entity': 'Aaron Rodgers'}
# {'text': 'A. Rodgers was traded to a new team during the Green Bay Packers.', 'entity': 'Aaron Rodgers'}
# {'text': 'The Quarterback attended a team strategy meeting at NBC Sports.', 'entity': 'Aaron Rodgers'}
# {'text': 'AR12 led a fourth-quarter comeback in Lambeau Field.', 'entity': 'Aaron Rodgers'}
# {'text': 'Aaron Rodgers gave an interview to the Green Bay Packers.', 'entity': 'Aaron Rodgers'}
# {'text': 'Rodgers signed a new contract with a quarterback camp.', 'entity': 'Aaron Rodgers'}
# {'text': 'NFL MVP participated in offseason training at the Green Bay Packers.', 'entity': 'Aaron Rodgers'}
# {'text': 'The Quarterback spoke on a podcast about the Pat McAfee Show.', 'entity': 'Aaron Rodgers'}
# {'text': 'Rodgers participated in offseason training at Lambeau Field.', 'entity': 'Aaron Rodgers'}
# {'text': 'Aaron Rodgers was traded to a new team during NFL Honors.', 'entity': 'Aaron Rodgers'}
# {'text': 'The Quarterback spoke on a podcast about the Pat McAfee Show.', 'entity': 'Aaron Rodgers'}
# {'text': 'Mr. Rodgers was traded to a new team during the New York Jets.', 'entity': 'Aaron Rodgers'}
# {'text': 'Green Bay QB was featured in a sports segment on CBS Sports.', 'entity': 'Aaron Rodgers'}
# {'text': 'Aaron Rodgers was traded to a new team during Lambeau Field.', 'entity': 'Aaron Rodgers'}
# {'text': 'Rodgers hosted a charity event at CBS Sports.', 'entity': 'Aaron Rodgers'}
# {'text': 'Aaron Rodgers spoke on a podcast about NBC Sports.', 'entity': 'Aaron Rodgers'}
# {'text': 'Aaron Rodgers spoke on a podcast about ESPN.', 'entity': 'Aaron Rodgers'}
# {'text': 'Aaron attended a team strategy meeting at a quarterback camp.', 'entity': 'Aaron Rodgers'}
# {'text': 'Mr. Rodgers participated in offseason training at the Pat McAfee Show.', 'entity': 'Aaron Rodgers'}
# {'text': 'A. Rodgers was traded to a new team during NFL Honors.', 'entity': 'Aaron Rodgers'}
# {'text': 'Mr. Rodgers hosted a charity event at CBS Sports.', 'entity': 'Aaron Rodgers'}
# {'text': 'Number 12 attended a team strategy meeting at Lambeau Field.', 'entity': 'Aaron Rodgers'}
# {'text': 'NFL MVP hosted a charity event at NBC Sports.', 'entity': 'Aaron Rodgers'}
# {'text': 'Rodgers participated in offseason training at NFL Honors.', 'entity': 'Aaron Rodgers'}
# {'text': 'Aaron was traded to a new team during the Pat McAfee Show.', 'entity': 'Aaron Rodgers'}
# {'text': 'Rodgers spoke on a podcast about the New York Jets.', 'entity': 'Aaron Rodgers'}
# {'text': 'Rodgers was featured in a sports segment on NFL Honors.', 'entity': 'Aaron Rodgers'}
# {'text': 'Mr. Rodgers led a fourth-quarter comeback in the New York Jets.', 'entity': 'Aaron Rodgers'}
# {'text': 'Mr. Rodgers participated in offseason training at the Green Bay Packers.', 'entity': 'Aaron Rodgers'}
# {'text': 'Rodgers spoke on a podcast about the New York Jets.', 'entity': 'Aaron Rodgers'}
# {'text': 'Number 12 signed a new contract with the Pat McAfee Show.', 'entity': 'Aaron Rodgers'}
# {'text': 'Aaron Rodgers announced his future plans during Lambeau Field.', 'entity': 'Aaron Rodgers'}
# {'text': 'Aaron Rodgers hosted a charity event at CBS Sports.', 'entity': 'Aaron Rodgers'}
# {'text': 'Number 12 spoke on a podcast about NFL Honors.', 'entity': 'Aaron Rodgers'}
# {'text': 'Number 12 attended a team strategy meeting at a quarterback camp.', 'entity': 'Aaron Rodgers'}
# {'text': 'NFL MVP was featured in a sports segment on the Green Bay Packers.', 'entity': 'Aaron Rodgers'}
# {'text': 'Aaron announced his future plans during Lambeau Field.', 'entity': 'Aaron Rodgers'}
# {'text': 'A. Rodgers announced his future plans during a quarterback camp.', 'entity': 'Aaron Rodgers'}
# {'text': 'Number 12 announced his future plans during NFL Honors.', 'entity': 'Aaron Rodgers'}
# {'text': 'Rodgers hosted a charity event at NFL Honors.', 'entity': 'Aaron Rodgers'}
# {'text': 'NFL MVP spoke on a podcast about NFL Honors.', 'entity': 'Aaron Rodgers'}
# {'text': 'Green Bay QB was featured in a sports segment on CBS Sports.', 'entity': 'Aaron Rodgers'}
# {'text': 'Green Bay QB signed a new contract with NBC Sports.', 'entity': 'Aaron Rodgers'}
# {'text': 'Aaron Rodgers announced his future plans during NFL Honors.', 'entity': 'Aaron Rodgers'}
# {'text': 'Number 12 signed a new contract with the New York Jets.', 'entity': 'Aaron Rodgers'}
# {'text': 'NFL MVP participated in offseason training at NFL Honors.', 'entity': 'Aaron Rodgers'}
# {'text': 'Mr. Rodgers attended a team strategy meeting at a quarterback camp.', 'entity': 'Aaron Rodgers'}
# {'text': 'The Quarterback gave an interview to Lambeau Field.', 'entity': 'Aaron Rodgers'}
# {'text': 'AR12 attended a team strategy meeting at the New York Jets.', 'entity': 'Aaron Rodgers'}
# {'text': 'Rodgers spoke on a podcast about the New York Jets.', 'entity': 'Aaron Rodgers'}
# {'text': 'Aaron Rodgers attended a team strategy meeting at a local Wisconsin fundraiser.', 'entity': 'Aaron Rodgers'}
# {'text': 'Number 12 participated in offseason training at the New York Jets.', 'entity': 'Aaron Rodgers'}
# {'text': 'Mr. Rodgers was traded to a new team during a local Wisconsin fundraiser.', 'entity': 'Aaron Rodgers'}
# {'text': 'AR12 was featured in a sports segment on NFL Honors.', 'entity': 'Aaron Rodgers'}
# {'text': 'AR12 gave an interview to the New York Jets.', 'entity': 'Aaron Rodgers'}
# {'text': 'Mr. Rodgers gave an interview to Lambeau Field.', 'entity': 'Aaron Rodgers'}
# {'text': 'AR12 spoke on a podcast about the New York Jets.', 'entity': 'Aaron Rodgers'}
# {'text': 'Aaron hosted a charity event at the Pat McAfee Show.', 'entity': 'Aaron Rodgers'}
# {'text': 'Number 12 signed a new contract with the Pat McAfee Show.', 'entity': 'Aaron Rodgers'}
# {'text': 'NFL MVP attended a team strategy meeting at the New York Jets.', 'entity': 'Aaron Rodgers'}
# {'text': 'NFL MVP spoke on a podcast about ESPN.', 'entity': 'Aaron Rodgers'}
# {'text': 'Green Bay QB signed a new contract with the Pat McAfee Show.', 'entity': 'Aaron Rodgers'}
# {'text': 'Green Bay QB was featured in a sports segment on a local Wisconsin fundraiser.', 'entity': 'Aaron Rodgers'}
# {'text': 'Mr. Rodgers gave an interview to NFL Honors.', 'entity': 'Aaron Rodgers'}
# {'text': 'Green Bay QB hosted a charity event at Lambeau Field.', 'entity': 'Aaron Rodgers'}
# {'text': 'Aaron Rodgers led a fourth-quarter comeback in NBC Sports.', 'entity': 'Aaron Rodgers'}
# {'text': 'Aaron hosted a charity event at the Pat McAfee Show.', 'entity': 'Aaron Rodgers'}
# {'text': 'NFL MVP attended a team strategy meeting at NFL Honors.', 'entity': 'Aaron Rodgers'}
# {'text': 'Aaron Rodgers was traded to a new team during the Green Bay Packers.', 'entity': 'Aaron Rodgers'}
# {'text': 'NFL MVP announced his future plans during a quarterback camp.', 'entity': 'Aaron Rodgers'}
# {'text': 'Rodgers announced his future plans during CBS Sports.', 'entity': 'Aaron Rodgers'}
# {'text': 'Aaron signed a new contract with a quarterback camp.', 'entity': 'Aaron Rodgers'}
# {'text': 'Mr. Rodgers was featured in a sports segment on the New York Jets.', 'entity': 'Aaron Rodgers'}
# {'text': 'Air Jordan won the NBA championship with ESPN.', 'entity': 'Michael Jordan'}
# {'text': 'M. Jordan was inducted into the Hall of Fame during ESPN.', 'entity': 'Michael Jordan'}
# {'text': 'His Airness announced his retirement from basketball in the Space Jam movie.', 'entity': 'Michael Jordan'}
# {'text': 'His Airness joined a roundtable discussion about Nike.', 'entity': 'Michael Jordan'}
# {'text': 'His Airness scored a game-winning shot in ESPN.', 'entity': 'Michael Jordan'}
# {'text': 'Number 23 released a new line of sneakers with ESPN.', 'entity': 'Michael Jordan'}
# {'text': 'M. Jordan scored a game-winning shot in NBA All-Star Weekend.', 'entity': 'Michael Jordan'}
# {'text': 'G.O.A.T. joined a roundtable discussion about Nike.', 'entity': 'Michael Jordan'}
# {'text': 'His Airness joined a roundtable discussion about the Dream Team.', 'entity': 'Michael Jordan'}
# {'text': 'MJ was featured in a documentary titled GQ Magazine.', 'entity': 'Michael Jordan'}
# {'text': 'M. Jordan was featured in a documentary titled NBA All-Star Weekend.', 'entity': 'Michael Jordan'}
# {'text': 'Mike announced his retirement from basketball in the Dream Team.', 'entity': 'Michael Jordan'}
# {'text': 'Mike Jordan played his final game with the Basketball Hall of Fame.', 'entity': 'Michael Jordan'}
# {'text': 'His Airness announced his retirement from basketball in the Dream Team.', 'entity': 'Michael Jordan'}
# {'text': 'Number 23 was inducted into the Hall of Fame during a sports summit.', 'entity': 'Michael Jordan'}
# {'text': 'Mike released a new line of sneakers with the 1998 NBA Finals.', 'entity': 'Michael Jordan'}
# {'text': 'Air Jordan won the NBA championship with the Chicago Bulls.', 'entity': 'Michael Jordan'}
# {'text': 'His Airness participated in a charity event hosted by NBA All-Star Weekend.', 'entity': 'Michael Jordan'}
# {'text': 'M. Jordan won the NBA championship with the Basketball Hall of Fame.', 'entity': 'Michael Jordan'}
# {'text': 'G.O.A.T. played his final game with NBA All-Star Weekend.', 'entity': 'Michael Jordan'}
# {'text': 'M. Jordan played his final game with GQ Magazine.', 'entity': 'Michael Jordan'}
# {'text': 'M. Jordan was featured in a documentary titled the 1998 NBA Finals.', 'entity': 'Michael Jordan'}
# {'text': 'M. Jordan announced his retirement from basketball in a sports summit.', 'entity': 'Michael Jordan'}
# {'text': 'Mike participated in a charity event hosted by the Basketball Hall of Fame.', 'entity': 'Michael Jordan'}
# {'text': 'Number 23 scored a game-winning shot in a sports summit.', 'entity': 'Michael Jordan'}
# {'text': 'His Airness won the NBA championship with GQ Magazine.', 'entity': 'Michael Jordan'}
# {'text': 'G.O.A.T. played his final game with the Chicago Bulls.', 'entity': 'Michael Jordan'}
# {'text': 'Michael Jordan signed a major endorsement deal with the Dream Team.', 'entity': 'Michael Jordan'}
# {'text': 'G.O.A.T. participated in a charity event hosted by GQ Magazine.', 'entity': 'Michael Jordan'}
# {'text': 'Mike joined a roundtable discussion about the Chicago Bulls.', 'entity': 'Michael Jordan'}
# {'text': 'His Airness won the NBA championship with the Basketball Hall of Fame.', 'entity': 'Michael Jordan'}
# {'text': 'MJ participated in a charity event hosted by the Dream Team.', 'entity': 'Michael Jordan'}
# {'text': 'Michael Jordan won the NBA championship with the Space Jam movie.', 'entity': 'Michael Jordan'}
# {'text': 'M. Jordan joined a roundtable discussion about the Basketball Hall of Fame.', 'entity': 'Michael Jordan'}
# {'text': 'Air Jordan signed a major endorsement deal with the 1998 NBA Finals.', 'entity': 'Michael Jordan'}
# {'text': 'Mike Jordan was inducted into the Hall of Fame during ESPN.', 'entity': 'Michael Jordan'}
# {'text': 'G.O.A.T. announced his retirement from basketball in ESPN.', 'entity': 'Michael Jordan'}
# {'text': 'Number 23 played his final game with the Dream Team.', 'entity': 'Michael Jordan'}
# {'text': 'His Airness joined a roundtable discussion about the 1998 NBA Finals.', 'entity': 'Michael Jordan'}
# {'text': 'M. Jordan was inducted into the Hall of Fame during the Chicago Bulls.', 'entity': 'Michael Jordan'}
# {'text': 'Mike Jordan was inducted into the Hall of Fame during the Basketball Hall of Fame.', 'entity': 'Michael Jordan'}
# {'text': 'Michael Jordan was inducted into the Hall of Fame during NBA All-Star Weekend.', 'entity': 'Michael Jordan'}
# {'text': 'Michael Jordan released a new line of sneakers with the 1998 NBA Finals.', 'entity': 'Michael Jordan'}
# {'text': 'M. Jordan signed a major endorsement deal with NBA All-Star Weekend.', 'entity': 'Michael Jordan'}
# {'text': 'Jordan was inducted into the Hall of Fame during Nike.', 'entity': 'Michael Jordan'}
# {'text': 'Jordan joined a roundtable discussion about the Space Jam movie.', 'entity': 'Michael Jordan'}
# {'text': 'Mike Jordan released a new line of sneakers with the Space Jam movie.', 'entity': 'Michael Jordan'}
# {'text': 'Mike was featured in a documentary titled GQ Magazine.', 'entity': 'Michael Jordan'}
# {'text': 'Air Jordan scored a game-winning shot in a sports summit.', 'entity': 'Michael Jordan'}
# {'text': 'Michael Jordan was inducted into the Hall of Fame during GQ Magazine.', 'entity': 'Michael Jordan'}
# {'text': 'His Airness was featured in a documentary titled the Space Jam movie.', 'entity': 'Michael Jordan'}
# {'text': 'Air Jordan was featured in a documentary titled GQ Magazine.', 'entity': 'Michael Jordan'}
# {'text': 'Mike Jordan played his final game with the Space Jam movie.', 'entity': 'Michael Jordan'}
# {'text': 'Number 23 joined a roundtable discussion about the Basketball Hall of Fame.', 'entity': 'Michael Jordan'}
# {'text': 'Mike Jordan was featured in a documentary titled GQ Magazine.', 'entity': 'Michael Jordan'}
# {'text': 'Air Jordan participated in a charity event hosted by the 1998 NBA Finals.', 'entity': 'Michael Jordan'}
# {'text': 'Air Jordan released a new line of sneakers with the Chicago Bulls.', 'entity': 'Michael Jordan'}
# {'text': 'His Airness participated in a charity event hosted by the Basketball Hall of Fame.', 'entity': 'Michael Jordan'}
# {'text': 'Number 23 released a new line of sneakers with a sports summit.', 'entity': 'Michael Jordan'}
# {'text': 'Mike Jordan was featured in a documentary titled GQ Magazine.', 'entity': 'Michael Jordan'}
# {'text': 'Air Jordan played his final game with Nike.', 'entity': 'Michael Jordan'}
# {'text': 'Mike Jordan participated in a charity event hosted by the 1998 NBA Finals.', 'entity': 'Michael Jordan'}
# {'text': 'Mike scored a game-winning shot in Nike.', 'entity': 'Michael Jordan'}
# {'text': 'M. Jordan scored a game-winning shot in the Basketball Hall of Fame.', 'entity': 'Michael Jordan'}
# {'text': 'G.O.A.T. scored a game-winning shot in the 1998 NBA Finals.', 'entity': 'Michael Jordan'}
# {'text': 'Michael Jordan scored a game-winning shot in Nike.', 'entity': 'Michael Jordan'}
# {'text': 'Michael Jordan won the NBA championship with the Space Jam movie.', 'entity': 'Michael Jordan'}
# {'text': 'Air Jordan was inducted into the Hall of Fame during Nike.', 'entity': 'Michael Jordan'}
# {'text': 'Michael Jordan was featured in a documentary titled Nike.', 'entity': 'Michael Jordan'}
# {'text': 'Mike Jordan scored a game-winning shot in NBA All-Star Weekend.', 'entity': 'Michael Jordan'}
# {'text': 'Jordan played his final game with NBA All-Star Weekend.', 'entity': 'Michael Jordan'}
# {'text': 'Air Jordan joined a roundtable discussion about NBA All-Star Weekend.', 'entity': 'Michael Jordan'}
# {'text': 'M. Jordan scored a game-winning shot in a sports summit.', 'entity': 'Michael Jordan'}
# {'text': 'M. Jordan joined a roundtable discussion about the 1998 NBA Finals.', 'entity': 'Michael Jordan'}
# {'text': 'Mike participated in a charity event hosted by the Dream Team.', 'entity': 'Michael Jordan'}
# {'text': 'Mike Jordan released a new line of sneakers with NBA All-Star Weekend.', 'entity': 'Michael Jordan'}
# {'text': 'Mike Jordan won the NBA championship with the Basketball Hall of Fame.', 'entity': 'Michael Jordan'}
# {'text': 'Air Jordan scored a game-winning shot in the Space Jam movie.', 'entity': 'Michael Jordan'}
# {'text': 'M. Jordan was featured in a documentary titled GQ Magazine.', 'entity': 'Michael Jordan'}
# {'text': 'Michael Jordan released a new line of sneakers with a sports summit.', 'entity': 'Michael Jordan'}
# {'text': 'His Airness joined a roundtable discussion about GQ Magazine.', 'entity': 'Michael Jordan'}
# {'text': 'M. Jordan announced his retirement from basketball in GQ Magazine.', 'entity': 'Michael Jordan'}
# {'text': 'Jordan announced his retirement from basketball in the 1998 NBA Finals.', 'entity': 'Michael Jordan'}
# {'text': 'Mike Jordan was inducted into the Hall of Fame during GQ Magazine.', 'entity': 'Michael Jordan'}
# {'text': 'M. Jordan joined a roundtable discussion about ESPN.', 'entity': 'Michael Jordan'}
# {'text': 'His Airness released a new line of sneakers with a sports summit.', 'entity': 'Michael Jordan'}
# {'text': 'MJ played his final game with a sports summit.', 'entity': 'Michael Jordan'}
# {'text': 'Michael Jordan participated in a charity event hosted by a sports summit.', 'entity': 'Michael Jordan'}
# {'text': 'Number 23 announced his retirement from basketball in GQ Magazine.', 'entity': 'Michael Jordan'}
# {'text': 'His Airness released a new line of sneakers with the 1998 NBA Finals.', 'entity': 'Michael Jordan'}
# {'text': 'Number 23 scored a game-winning shot in ESPN.', 'entity': 'Michael Jordan'}
# {'text': 'MJ played his final game with the Basketball Hall of Fame.', 'entity': 'Michael Jordan'}
# {'text': 'Number 23 participated in a charity event hosted by NBA All-Star Weekend.', 'entity': 'Michael Jordan'}
# {'text': 'Mike Jordan released a new line of sneakers with the Basketball Hall of Fame.', 'entity': 'Michael Jordan'}
# {'text': 'Jordan was inducted into the Hall of Fame during the Space Jam movie.', 'entity': 'Michael Jordan'}
# {'text': 'M. Jordan was inducted into the Hall of Fame during the Space Jam movie.', 'entity': 'Michael Jordan'}
# {'text': 'G.O.A.T. released a new line of sneakers with the Basketball Hall of Fame.', 'entity': 'Michael Jordan'}
# {'text': 'Jordan joined a roundtable discussion about the Dream Team.', 'entity': 'Michael Jordan'}
# {'text': 'Mike Jordan was featured in a documentary titled NBA All-Star Weekend.', 'entity': 'Michael Jordan'}
# {'text': 'G.O.A.T. released a new line of sneakers with the Chicago Bulls.', 'entity': 'Michael Jordan'}
# {'text': 'Steve Jobs delivered a keynote speech during MIT Technology Review.', 'entity': 'Steve Jobs'}
# {'text': 'Mr. Jobs delivered a keynote speech during MIT Technology Review.', 'entity': 'Steve Jobs'}
# {'text': 'Apple Co-Founder announced a partnership with the Apple Event.', 'entity': 'Steve Jobs'}
# {'text': 'Mr. Jobs was featured in a documentary aired on Macworld.', 'entity': 'Steve Jobs'}
# {'text': 'Tech Visionary led a strategic planning session at Time Magazine.', 'entity': 'Steve Jobs'}
# {'text': 'Jobs launched a new innovation in the Apple Campus.', 'entity': 'Steve Jobs'}
# {'text': 'Steve Jobs announced a partnership with Silicon Valley.', 'entity': 'Steve Jobs'}
# {'text': 'Apple Co-Founder was featured in a documentary aired on Stanford University.', 'entity': 'Steve Jobs'}
# {'text': 'Jobs was featured in a documentary aired on Time Magazine.', 'entity': 'Steve Jobs'}
# {'text': 'Steven P. Jobs launched a new innovation in the iPhone launch.', 'entity': 'Steve Jobs'}
# {'text': 'Steven P. Jobs held an executive meeting in WWDC.', 'entity': 'Steve Jobs'}
# {'text': 'Tech Visionary was recognized for his contributions to technology at Macworld.', 'entity': 'Steve Jobs'}
# {'text': 'The Innovator announced a partnership with Silicon Valley.', 'entity': 'Steve Jobs'}
# {'text': 'Mr. Jobs delivered a keynote speech during PBS.', 'entity': 'Steve Jobs'}
# {'text': 'Tech Visionary delivered a keynote speech during the Apple Campus.', 'entity': 'Steve Jobs'}
# {'text': 'Jobs unveiled a groundbreaking product at Stanford University.', 'entity': 'Steve Jobs'}
# {'text': 'Mr. Jobs unveiled a groundbreaking product at Stanford University.', 'entity': 'Steve Jobs'}
# {'text': 'The Product Genius was recognized for his contributions to technology at the Apple Campus.', 'entity': 'Steve Jobs'}
# {'text': 'The Innovator unveiled a groundbreaking product at Time Magazine.', 'entity': 'Steve Jobs'}
# {'text': 'Jobs launched a new innovation in the Apple Campus.', 'entity': 'Steve Jobs'}
# {'text': 'Steven P. Jobs led a strategic planning session at PBS.', 'entity': 'Steve Jobs'}
# {'text': 'Mr. Jobs appeared on the cover of MIT Technology Review.', 'entity': 'Steve Jobs'}
# {'text': 'Tech Visionary led a strategic planning session at the Apple Event.', 'entity': 'Steve Jobs'}
# {'text': 'Mr. Jobs was featured in a documentary aired on the Apple Event.', 'entity': 'Steve Jobs'}
# {'text': 'Apple Co-Founder announced a partnership with the Apple Campus.', 'entity': 'Steve Jobs'}
# {'text': 'The Product Genius led a strategic planning session at Stanford University.', 'entity': 'Steve Jobs'}
# {'text': 'Steve Jobs delivered a keynote speech during WWDC.', 'entity': 'Steve Jobs'}
# {'text': 'Steven P. Jobs was interviewed about design at Stanford University.', 'entity': 'Steve Jobs'}
# {'text': 'Tech Visionary was interviewed about design at the iPhone launch.', 'entity': 'Steve Jobs'}
# {'text': 'Mr. Jobs launched a new innovation in WWDC.', 'entity': 'Steve Jobs'}
# {'text': 'Apple Co-Founder appeared on the cover of Stanford University.', 'entity': 'Steve Jobs'}
# {'text': 'Apple Co-Founder led a strategic planning session at the iPhone launch.', 'entity': 'Steve Jobs'}
# {'text': 'The Innovator was interviewed about design at Time Magazine.', 'entity': 'Steve Jobs'}
# {'text': 'Steven P. Jobs appeared on the cover of PBS.', 'entity': 'Steve Jobs'}
# {'text': 'Mr. Jobs was featured in a documentary aired on MIT Technology Review.', 'entity': 'Steve Jobs'}
# {'text': 'Tech Visionary announced a partnership with the Apple Event.', 'entity': 'Steve Jobs'}
# {'text': 'Tech Visionary held an executive meeting in Time Magazine.', 'entity': 'Steve Jobs'}
# {'text': 'Mr. Jobs was interviewed about design at the Apple Campus.', 'entity': 'Steve Jobs'}
# {'text': 'Apple Co-Founder delivered a keynote speech during WWDC.', 'entity': 'Steve Jobs'}
# {'text': 'Apple Co-Founder unveiled a groundbreaking product at the iPhone launch.', 'entity': 'Steve Jobs'}
# {'text': 'The Product Genius was featured in a documentary aired on MIT Technology Review.', 'entity': 'Steve Jobs'}
# {'text': 'S. Jobs appeared on the cover of PBS.', 'entity': 'Steve Jobs'}
# {'text': 'S. Jobs unveiled a groundbreaking product at the Apple Event.', 'entity': 'Steve Jobs'}
# {'text': 'S. Jobs launched a new innovation in Macworld.', 'entity': 'Steve Jobs'}
# {'text': 'The Product Genius appeared on the cover of the Apple Campus.', 'entity': 'Steve Jobs'}
# {'text': 'Jobs was featured in a documentary aired on Time Magazine.', 'entity': 'Steve Jobs'}
# {'text': 'Steve Jobs launched a new innovation in Silicon Valley.', 'entity': 'Steve Jobs'}
# {'text': 'The Product Genius delivered a keynote speech during the Apple Campus.', 'entity': 'Steve Jobs'}
# {'text': 'S. Jobs delivered a keynote speech during the iPhone launch.', 'entity': 'Steve Jobs'}
# {'text': 'Apple Co-Founder launched a new innovation in Silicon Valley.', 'entity': 'Steve Jobs'}
# {'text': 'The Innovator unveiled a groundbreaking product at the Apple Campus.', 'entity': 'Steve Jobs'}
# {'text': 'The Product Genius was interviewed about design at PBS.', 'entity': 'Steve Jobs'}
# {'text': 'Jobs was interviewed about design at Silicon Valley.', 'entity': 'Steve Jobs'}
# {'text': 'Steve Jobs appeared on the cover of the iPhone launch.', 'entity': 'Steve Jobs'}
# {'text': 'The Innovator was recognized for his contributions to technology at MIT Technology Review.', 'entity': 'Steve Jobs'}
# {'text': 'iCEO led a strategic planning session at the iPhone launch.', 'entity': 'Steve Jobs'}
# {'text': 'Steve Jobs delivered a keynote speech during Macworld.', 'entity': 'Steve Jobs'}
# {'text': 'Tech Visionary was interviewed about design at the iPhone launch.', 'entity': 'Steve Jobs'}
# {'text': 'Tech Visionary launched a new innovation in the Apple Campus.', 'entity': 'Steve Jobs'}
# {'text': 'Tech Visionary was recognized for his contributions to technology at the iPhone launch.', 'entity': 'Steve Jobs'}
# {'text': 'iCEO delivered a keynote speech during the Apple Campus.', 'entity': 'Steve Jobs'}
# {'text': 'Apple Co-Founder announced a partnership with the iPhone launch.', 'entity': 'Steve Jobs'}
# {'text': 'The Innovator announced a partnership with the Apple Campus.', 'entity': 'Steve Jobs'}
# {'text': 'iCEO unveiled a groundbreaking product at the iPhone launch.', 'entity': 'Steve Jobs'}
# {'text': 'Jobs held an executive meeting in Time Magazine.', 'entity': 'Steve Jobs'}
# {'text': 'Mr. Jobs led a strategic planning session at Macworld.', 'entity': 'Steve Jobs'}
# {'text': 'Steve Jobs held an executive meeting in Time Magazine.', 'entity': 'Steve Jobs'}
# {'text': 'iCEO was featured in a documentary aired on Time Magazine.', 'entity': 'Steve Jobs'}
# {'text': 'The Product Genius delivered a keynote speech during WWDC.', 'entity': 'Steve Jobs'}
# {'text': 'Steven P. Jobs announced a partnership with Macworld.', 'entity': 'Steve Jobs'}
# {'text': 'Tech Visionary led a strategic planning session at the iPhone launch.', 'entity': 'Steve Jobs'}
# {'text': 'Steve Jobs launched a new innovation in the Apple Campus.', 'entity': 'Steve Jobs'}
# {'text': 'Tech Visionary appeared on the cover of PBS.', 'entity': 'Steve Jobs'}
# {'text': 'Apple Co-Founder was recognized for his contributions to technology at the iPhone launch.', 'entity': 'Steve Jobs'}
# {'text': 'Tech Visionary launched a new innovation in the Apple Campus.', 'entity': 'Steve Jobs'}
# {'text': 'The Product Genius was recognized for his contributions to technology at PBS.', 'entity': 'Steve Jobs'}
# {'text': 'The Product Genius appeared on the cover of Stanford University.', 'entity': 'Steve Jobs'}
# {'text': 'S. Jobs was interviewed about design at Macworld.', 'entity': 'Steve Jobs'}
# {'text': 'Steve Jobs unveiled a groundbreaking product at Stanford University.', 'entity': 'Steve Jobs'}
# {'text': 'iCEO was interviewed about design at the Apple Event.', 'entity': 'Steve Jobs'}
# {'text': 'Mr. Jobs announced a partnership with MIT Technology Review.', 'entity': 'Steve Jobs'}
# {'text': 'Apple Co-Founder was recognized for his contributions to technology at PBS.', 'entity': 'Steve Jobs'}
# {'text': 'Tech Visionary delivered a keynote speech during Silicon Valley.', 'entity': 'Steve Jobs'}
# {'text': 'Steven P. Jobs was interviewed about design at the Apple Event.', 'entity': 'Steve Jobs'}
# {'text': 'Tech Visionary held an executive meeting in Silicon Valley.', 'entity': 'Steve Jobs'}
# {'text': 'The Innovator launched a new innovation in WWDC.', 'entity': 'Steve Jobs'}
# {'text': 'Mr. Jobs was recognized for his contributions to technology at Macworld.', 'entity': 'Steve Jobs'}
# {'text': 'Steve Jobs launched a new innovation in Macworld.', 'entity': 'Steve Jobs'}
# {'text': 'Jobs held an executive meeting in the Apple Campus.', 'entity': 'Steve Jobs'}
# {'text': 'iCEO appeared on the cover of Time Magazine.', 'entity': 'Steve Jobs'}
# {'text': 'Mr. Jobs announced a partnership with the iPhone launch.', 'entity': 'Steve Jobs'}
# {'text': 'Mr. Jobs was interviewed about design at the Apple Event.', 'entity': 'Steve Jobs'}
# {'text': 'The Product Genius launched a new innovation in the iPhone launch.', 'entity': 'Steve Jobs'}
# {'text': 'Mr. Jobs led a strategic planning session at PBS.', 'entity': 'Steve Jobs'}
# {'text': 'Steven P. Jobs appeared on the cover of MIT Technology Review.', 'entity': 'Steve Jobs'}
# {'text': 'Steven P. Jobs was featured in a documentary aired on MIT Technology Review.', 'entity': 'Steve Jobs'}
# {'text': 'Steve Jobs appeared on the cover of WWDC.', 'entity': 'Steve Jobs'}
# {'text': 'The Product Genius was interviewed about design at Stanford University.', 'entity': 'Steve Jobs'}
# {'text': 'S. Jobs was featured in a documentary aired on Time Magazine.', 'entity': 'Steve Jobs'}
# {'text': 'Mr. Jobs was recognized for his contributions to technology at Silicon Valley.', 'entity': 'Steve Jobs'}
# {'text': 'President Putin chaired a security council meeting about St. Petersburg.', 'entity': 'Vladimir Putin'}
# {'text': 'V. Putin addressed the nation during St. Petersburg.', 'entity': 'Vladimir Putin'}
# {'text': 'V. Putin signed a strategic agreement with the Black Sea.', 'entity': 'Vladimir Putin'}
# {'text': 'Vlad held a press conference regarding the UN General Assembly.', 'entity': 'Vladimir Putin'}
# {'text': 'Vladimir Putin signed a strategic agreement with the G20 Summit.', 'entity': 'Vladimir Putin'}
# {'text': 'The Kremlin Leader signed a strategic agreement with RT News.', 'entity': 'Vladimir Putin'}
# {'text': 'Commander-in-Chief announced new foreign policy measures at RT News.', 'entity': 'Vladimir Putin'}
# {'text': 'Commander-in-Chief spoke at a global forum hosted in the G20 Summit.', 'entity': 'Vladimir Putin'}
# {'text': 'Mr. Putin announced new foreign policy measures at a bilateral summit with China.', 'entity': 'Vladimir Putin'}
# {'text': 'Russian President was featured in international media discussing the State Duma.', 'entity': 'Vladimir Putin'}
# {'text': 'Commander-in-Chief chaired a security council meeting about Moscow.', 'entity': 'Vladimir Putin'}
# {'text': 'Commander-in-Chief announced new foreign policy measures at the Ministry of Defense.', 'entity': 'Vladimir Putin'}
# {'text': 'Putin visited a major infrastructure project in RT News.', 'entity': 'Vladimir Putin'}
# {'text': 'President Putin was featured in international media discussing the Ministry of Defense.', 'entity': 'Vladimir Putin'}
# {'text': 'Putin met with foreign diplomats in the G20 Summit.', 'entity': 'Vladimir Putin'}
# {'text': 'Head of State was featured in international media discussing the State Duma.', 'entity': 'Vladimir Putin'}
# {'text': 'Russian President spoke at a global forum hosted in the Black Sea.', 'entity': 'Vladimir Putin'}
# {'text': 'V. Putin announced new foreign policy measures at St. Petersburg.', 'entity': 'Vladimir Putin'}
# {'text': 'President Putin chaired a security council meeting about St. Petersburg.', 'entity': 'Vladimir Putin'}
# {'text': 'Head of State was featured in international media discussing the UN General Assembly.', 'entity': 'Vladimir Putin'}
# {'text': 'Vlad met with foreign diplomats in the Kremlin.', 'entity': 'Vladimir Putin'}
# {'text': 'The Kremlin Leader oversaw military exercises near a bilateral summit with China.', 'entity': 'Vladimir Putin'}
# {'text': 'Vlad addressed the nation during the Black Sea.', 'entity': 'Vladimir Putin'}
# {'text': 'The Kremlin Leader met with foreign diplomats in Moscow.', 'entity': 'Vladimir Putin'}
# {'text': 'Vlad addressed the nation during the Ministry of Defense.', 'entity': 'Vladimir Putin'}
# {'text': 'President Putin oversaw military exercises near a bilateral summit with China.', 'entity': 'Vladimir Putin'}
# {'text': 'Putin held a press conference regarding the Black Sea.', 'entity': 'Vladimir Putin'}
# {'text': 'Russian President addressed the nation during St. Petersburg.', 'entity': 'Vladimir Putin'}
# {'text': 'Putin was featured in international media discussing St. Petersburg.', 'entity': 'Vladimir Putin'}
# {'text': 'Putin chaired a security council meeting about the G20 Summit.', 'entity': 'Vladimir Putin'}
# {'text': 'Commander-in-Chief signed a strategic agreement with St. Petersburg.', 'entity': 'Vladimir Putin'}
# {'text': 'Head of State held a press conference regarding the State Duma.', 'entity': 'Vladimir Putin'}
# {'text': 'Vladimir Putin chaired a security council meeting about the Black Sea.', 'entity': 'Vladimir Putin'}
# {'text': 'Vlad was featured in international media discussing RT News.', 'entity': 'Vladimir Putin'}
# {'text': 'Head of State was featured in international media discussing the Kremlin.', 'entity': 'Vladimir Putin'}
# {'text': 'V. Putin met with foreign diplomats in Moscow.', 'entity': 'Vladimir Putin'}
# {'text': 'Mr. Putin oversaw military exercises near St. Petersburg.', 'entity': 'Vladimir Putin'}
# {'text': 'Mr. Putin addressed the nation during the State Duma.', 'entity': 'Vladimir Putin'}
# {'text': 'Commander-in-Chief was featured in international media discussing the G20 Summit.', 'entity': 'Vladimir Putin'}
# {'text': 'Commander-in-Chief chaired a security council meeting about St. Petersburg.', 'entity': 'Vladimir Putin'}
# {'text': 'Mr. Putin was featured in international media discussing the Kremlin.', 'entity': 'Vladimir Putin'}
# {'text': 'Commander-in-Chief signed a strategic agreement with the Ministry of Defense.', 'entity': 'Vladimir Putin'}
# {'text': 'Russian President chaired a security council meeting about the Kremlin.', 'entity': 'Vladimir Putin'}
# {'text': 'Vladimir Putin addressed the nation during the Ministry of Defense.', 'entity': 'Vladimir Putin'}
# {'text': 'Commander-in-Chief signed a strategic agreement with the Kremlin.', 'entity': 'Vladimir Putin'}
# {'text': 'V. Putin visited a major infrastructure project in Moscow.', 'entity': 'Vladimir Putin'}
# {'text': 'Mr. Putin held a press conference regarding the State Duma.', 'entity': 'Vladimir Putin'}
# {'text': 'Putin announced new foreign policy measures at the Kremlin.', 'entity': 'Vladimir Putin'}
# {'text': 'Mr. Putin visited a major infrastructure project in the UN General Assembly.', 'entity': 'Vladimir Putin'}
# {'text': 'Vladimir Putin held a press conference regarding RT News.', 'entity': 'Vladimir Putin'}
# {'text': 'Head of State signed a strategic agreement with the UN General Assembly.', 'entity': 'Vladimir Putin'}
# {'text': 'Head of State addressed the nation during the State Duma.', 'entity': 'Vladimir Putin'}
# {'text': 'Putin signed a strategic agreement with a bilateral summit with China.', 'entity': 'Vladimir Putin'}
# {'text': 'Mr. Putin oversaw military exercises near the Kremlin.', 'entity': 'Vladimir Putin'}
# {'text': 'Mr. Putin met with foreign diplomats in St. Petersburg.', 'entity': 'Vladimir Putin'}
# {'text': 'Commander-in-Chief chaired a security council meeting about the Ministry of Defense.', 'entity': 'Vladimir Putin'}
# {'text': 'Mr. Putin signed a strategic agreement with the Ministry of Defense.', 'entity': 'Vladimir Putin'}
# {'text': 'V. Putin oversaw military exercises near Moscow.', 'entity': 'Vladimir Putin'}
# {'text': 'The Kremlin Leader oversaw military exercises near the Ministry of Defense.', 'entity': 'Vladimir Putin'}
# {'text': 'Mr. Putin held a press conference regarding St. Petersburg.', 'entity': 'Vladimir Putin'}
# {'text': 'Mr. Putin announced new foreign policy measures at the UN General Assembly.', 'entity': 'Vladimir Putin'}
# {'text': 'Mr. Putin visited a major infrastructure project in the Kremlin.', 'entity': 'Vladimir Putin'}
# {'text': 'Commander-in-Chief visited a major infrastructure project in RT News.', 'entity': 'Vladimir Putin'}
# {'text': 'Russian President addressed the nation during the G20 Summit.', 'entity': 'Vladimir Putin'}
# {'text': 'Mr. Putin met with foreign diplomats in a bilateral summit with China.', 'entity': 'Vladimir Putin'}
# {'text': 'Vladimir Putin announced new foreign policy measures at the G20 Summit.', 'entity': 'Vladimir Putin'}
# {'text': 'Mr. Putin was featured in international media discussing the Kremlin.', 'entity': 'Vladimir Putin'}
# {'text': 'Vladimir Putin visited a major infrastructure project in Moscow.', 'entity': 'Vladimir Putin'}
# {'text': 'V. Putin chaired a security council meeting about the Kremlin.', 'entity': 'Vladimir Putin'}
# {'text': 'Head of State signed a strategic agreement with the UN General Assembly.', 'entity': 'Vladimir Putin'}
# {'text': 'Vlad held a press conference regarding the Ministry of Defense.', 'entity': 'Vladimir Putin'}
# {'text': 'Mr. Putin oversaw military exercises near the Kremlin.', 'entity': 'Vladimir Putin'}
# {'text': 'The Kremlin Leader chaired a security council meeting about the G20 Summit.', 'entity': 'Vladimir Putin'}
# {'text': 'President Putin met with foreign diplomats in the Black Sea.', 'entity': 'Vladimir Putin'}
# {'text': 'The Kremlin Leader visited a major infrastructure project in the Ministry of Defense.', 'entity': 'Vladimir Putin'}
# {'text': 'The Kremlin Leader signed a strategic agreement with Moscow.', 'entity': 'Vladimir Putin'}
# {'text': 'V. Putin oversaw military exercises near the Kremlin.', 'entity': 'Vladimir Putin'}
# {'text': 'The Kremlin Leader held a press conference regarding St. Petersburg.', 'entity': 'Vladimir Putin'}
# {'text': 'Vlad visited a major infrastructure project in the Ministry of Defense.', 'entity': 'Vladimir Putin'}
# {'text': 'Vladimir Putin was featured in international media discussing a bilateral summit with China.', 'entity': 'Vladimir Putin'}
# {'text': 'Commander-in-Chief chaired a security council meeting about the Kremlin.', 'entity': 'Vladimir Putin'}
# {'text': 'Commander-in-Chief held a press conference regarding the G20 Summit.', 'entity': 'Vladimir Putin'}
# {'text': 'Commander-in-Chief chaired a security council meeting about the Black Sea.', 'entity': 'Vladimir Putin'}
# {'text': 'President Putin chaired a security council meeting about the Black Sea.', 'entity': 'Vladimir Putin'}
# {'text': 'Commander-in-Chief spoke at a global forum hosted in the UN General Assembly.', 'entity': 'Vladimir Putin'}
# {'text': 'President Putin met with foreign diplomats in St. Petersburg.', 'entity': 'Vladimir Putin'}
# {'text': 'President Putin spoke at a global forum hosted in Moscow.', 'entity': 'Vladimir Putin'}
# {'text': 'Mr. Putin was featured in international media discussing St. Petersburg.', 'entity': 'Vladimir Putin'}
# {'text': 'Head of State chaired a security council meeting about the Ministry of Defense.', 'entity': 'Vladimir Putin'}
# {'text': 'President Putin held a press conference regarding Moscow.', 'entity': 'Vladimir Putin'}
# {'text': 'Vlad held a press conference regarding the Ministry of Defense.', 'entity': 'Vladimir Putin'}
# {'text': 'Head of State announced new foreign policy measures at the UN General Assembly.', 'entity': 'Vladimir Putin'}
# {'text': 'Putin met with foreign diplomats in RT News.', 'entity': 'Vladimir Putin'}
# {'text': 'Putin was featured in international media discussing a bilateral summit with China.', 'entity': 'Vladimir Putin'}
# {'text': 'V. Putin held a press conference regarding the State Duma.', 'entity': 'Vladimir Putin'}
# {'text': 'President Putin spoke at a global forum hosted in Moscow.', 'entity': 'Vladimir Putin'}
# {'text': 'Commander-in-Chief spoke at a global forum hosted in Moscow.', 'entity': 'Vladimir Putin'}
# {'text': 'Mr. Putin met with foreign diplomats in Moscow.', 'entity': 'Vladimir Putin'}
# {'text': 'Russian President spoke at a global forum hosted in the Kremlin.', 'entity': 'Vladimir Putin'}
# {'text': 'Vladimir Putin visited a major infrastructure project in the Ministry of Defense.', 'entity': 'Vladimir Putin'}
# {'text': 'China Forward Logistics was granted exclusive access to infrastructure in Silicon Valley.', 'entity': nan}
# {'text': 'B.E.I. Trading launched a new tech product in South America.', 'entity': nan}
# {'text': 'Shenzhen Global Trade was investigated for regulatory violations in the Middle East.', 'entity': nan}
# {'text': 'Shenzhen Global Trade signed a shipping deal with distributors in South America.', 'entity': nan}
# {'text': 'Zhenhua Group held a high-level summit with investors in South America.', 'entity': nan}
# {'text': 'B.E.I. Trading secured a trade agreement with South America.', 'entity': nan}
# {'text': 'Shenzhen Global Trade announced an international expansion into Silicon Valley.', 'entity': nan}
# {'text': 'Red Dragon Holdings signed a shipping deal with distributors in Silicon Valley.', 'entity': nan}
# {'text': 'Beijing Innovations Ltd. announced an international expansion into South America.', 'entity': nan}
# {'text': 'Beijing Innovations Ltd. signed a shipping deal with distributors in New Delhi.', 'entity': nan}
# {'text': 'Beijing Innovations Ltd. partnered with a foreign firm based in the ASEAN bloc.', 'entity': nan}
# {'text': 'Beijing Innovations Ltd. was investigated for regulatory violations in Kenya.', 'entity': nan}
# {'text': 'B.E.I. Trading launched a new tech product in the Middle East.', 'entity': nan}
# {'text': 'SinoTech International was investigated for regulatory violations in Kenya.', 'entity': nan}
# {'text': 'China Forward Logistics secured a trade agreement with Kenya.', 'entity': nan}
# {'text': 'DragonStar Industries opened a regional office in the European Union.', 'entity': nan}
# {'text': 'Guangzhou Unified Exports announced an international expansion into the Middle East.', 'entity': nan}
# {'text': 'The Eastern Consortium opened a regional office in Kenya.', 'entity': nan}
# {'text': 'Guangzhou Unified Exports was featured in a global market report from South America.', 'entity': nan}
# {'text': 'SinoTech International launched a new tech product in Silicon Valley.', 'entity': nan}
# {'text': 'DragonStar Industries partnered with a foreign firm based in the Port of Hamburg.', 'entity': nan}
# {'text': 'Shenzhen Global Trade signed a shipping deal with distributors in the Middle East.', 'entity': nan}
# {'text': 'Zhenhua Group was featured in a global market report from the Port of Hamburg.', 'entity': nan}
# {'text': 'The Eastern Consortium was featured in a global market report from the Middle East.', 'entity': nan}
# {'text': 'Guangzhou Unified Exports launched a new tech product in Kenya.', 'entity': nan}
# {'text': 'Guangzhou Unified Exports was featured in a global market report from New Delhi.', 'entity': nan}
# {'text': 'SinoTech International partnered with a foreign firm based in Kenya.', 'entity': nan}
# {'text': 'DragonStar Industries was investigated for regulatory violations in Singapore.', 'entity': nan}
# {'text': 'B.E.I. Trading signed a shipping deal with distributors in Kenya.', 'entity': nan}
# {'text': 'Red Dragon Holdings launched a new tech product in South America.', 'entity': nan}
# {'text': 'DragonStar Industries partnered with a foreign firm based in the Middle East.', 'entity': nan}
# {'text': 'Red Dragon Holdings announced an international expansion into Kenya.', 'entity': nan}
# {'text': 'B.E.I. Trading held a high-level summit with investors in New Delhi.', 'entity': nan}
# {'text': 'DragonStar Industries was investigated for regulatory violations in Silicon Valley.', 'entity': nan}
# {'text': 'SinoTech International opened a regional office in the Middle East.', 'entity': nan}
# {'text': 'DragonStar Industries held a high-level summit with investors in the Port of Hamburg.', 'entity': nan}
# {'text': 'B.E.I. Trading partnered with a foreign firm based in Silicon Valley.', 'entity': nan}
# {'text': 'Shenzhen Global Trade was granted exclusive access to infrastructure in Singapore.', 'entity': nan}
# {'text': 'Red Dragon Holdings launched a new tech product in the ASEAN bloc.', 'entity': nan}
# {'text': 'DragonStar Industries announced an international expansion into New Delhi.', 'entity': nan}
# {'text': 'China Forward Logistics was granted exclusive access to infrastructure in the Suez Canal.', 'entity': nan}
# {'text': 'Guangzhou Unified Exports launched a new tech product in the Middle East.', 'entity': nan}
# {'text': 'The Eastern Consortium launched a new tech product in New Delhi.', 'entity': nan}
# {'text': 'Beijing Innovations Ltd. announced an international expansion into the Port of Hamburg.', 'entity': nan}
# {'text': 'B.E.I. Trading opened a regional office in Silicon Valley.', 'entity': nan}
# {'text': 'China Forward Logistics signed a shipping deal with distributors in Singapore.', 'entity': nan}
# {'text': 'Shenzhen Global Trade signed a shipping deal with distributors in Kenya.', 'entity': nan}
# {'text': 'DragonStar Industries opened a regional office in South America.', 'entity': nan}
# {'text': 'Shenzhen Global Trade held a high-level summit with investors in the Suez Canal.', 'entity': nan}
# {'text': 'China Forward Logistics signed a shipping deal with distributors in South America.', 'entity': nan}
# {'text': 'Beijing Innovations Ltd. announced an international expansion into New Delhi.', 'entity': nan}
# {'text': 'Beijing Innovations Ltd. opened a regional office in South America.', 'entity': nan}
# {'text': 'SinoTech International signed a shipping deal with distributors in the ASEAN bloc.', 'entity': nan}
# {'text': 'Beijing Innovations Ltd. was featured in a global market report from South America.', 'entity': nan}
# {'text': 'Beijing Innovations Ltd. held a high-level summit with investors in the Middle East.', 'entity': nan}
# {'text': 'SinoTech International held a high-level summit with investors in the Suez Canal.', 'entity': nan}
# {'text': 'The Eastern Consortium held a high-level summit with investors in the Port of Hamburg.', 'entity': nan}
# {'text': 'B.E.I. Trading held a high-level summit with investors in the Port of Hamburg.', 'entity': nan}
# {'text': 'B.E.I. Trading held a high-level summit with investors in the ASEAN bloc.', 'entity': nan}
# {'text': 'Zhenhua Group launched a new tech product in New Delhi.', 'entity': nan}
# {'text': 'DragonStar Industries launched a new tech product in Singapore.', 'entity': nan}
# {'text': 'DragonStar Industries launched a new tech product in the Port of Hamburg.', 'entity': nan}
# {'text': 'DragonStar Industries announced an international expansion into Singapore.', 'entity': nan}
# {'text': 'Guangzhou Unified Exports was investigated for regulatory violations in the Port of Hamburg.', 'entity': nan}
# {'text': 'Beijing Innovations Ltd. opened a regional office in New Delhi.', 'entity': nan}
# {'text': 'Shenzhen Global Trade was investigated for regulatory violations in the Middle East.', 'entity': nan}
# {'text': 'Beijing Innovations Ltd. was granted exclusive access to infrastructure in the European Union.', 'entity': nan}
# {'text': 'China Forward Logistics opened a regional office in Singapore.', 'entity': nan}
# {'text': 'Red Dragon Holdings held a high-level summit with investors in the Port of Hamburg.', 'entity': nan}
# {'text': 'Beijing Innovations Ltd. was featured in a global market report from the Middle East.', 'entity': nan}
# {'text': 'Zhenhua Group was featured in a global market report from New Delhi.', 'entity': nan}
# {'text': 'The Eastern Consortium announced an international expansion into Singapore.', 'entity': nan}
# ...
# {'text': 'T Swift revealed behind-the-scenes footage from a fan meet-up.', 'entity': nan}
# {'text': 'T Swift was featured in a documentary about the Eras Tour.', 'entity': nan}
# {'text': 'Swift collaborated with another artist in a fan meet-up.', 'entity': nan}
# {'text': 'Taylor won an award for best artist at Netflix.', 'entity': nan}
# {'text': 'Taylor S revealed behind-the-scenes footage from a fan meet-up.', 'entity': nan}
# {'text': 'Swift collaborated with another artist in the Eras Tour.', 'entity': nan}
# {'text': 'Taylor Swift appeared on a late-night show to promote New York.', 'entity': nan}
# {'text': 'Ms. Swift won an award for best artist at an exclusive interview.', 'entity': nan}
# {'text': 'Taylor S announced a world tour during New York.', 'entity': nan}
# {'text': 'Taylor S appeared on a late-night show to promote an exclusive interview.', 'entity': nan}
# {'text': 'T Swift won an award for best artist at Los Angeles.', 'entity': nan}
# {'text': 'T Swift performed a sold-out concert in Paris.', 'entity': nan}
# {'text': 'Taylor Swift appeared on a late-night show to promote an exclusive interview.', 'entity': nan}
# {'text': 'TayTay announced a world tour during Spotify.', 'entity': nan}
# {'text': 'Swift revealed behind-the-scenes footage from a fan meet-up.', 'entity': nan}
# {'text': 'TayTay appeared on a late-night show to promote New York.', 'entity': nan}
# {'text': 'Taylor Swift was featured in a documentary about the Eras Tour.', 'entity': nan}
# {'text': 'Swift revealed behind-the-scenes footage from Los Angeles.', 'entity': nan}
# {'text': 'T Swift announced a world tour during a fan meet-up.', 'entity': nan}
# {'text': 'Taylor released a new single titled the Grammy Awards.', 'entity': nan}
# {'text': 'Swift appeared on a late-night show to promote Netflix.', 'entity': nan}
# {'text': 'Swift spoke about her songwriting process in the Grammy Awards.', 'entity': nan}
# {'text': 'Ms. Swift engaged with fans during a live session on Netflix.', 'entity': nan}
# {'text': 'Taylor won an award for best artist at the Grammy Awards.', 'entity': nan}
# {'text': 'Taylor Swift was featured in a documentary about Los Angeles.', 'entity': nan}
# {'text': 'Taylor engaged with fans during a live session on New York.', 'entity': nan}
# {'text': 'Swift released a new single titled the Eras Tour.', 'entity': nan}
# {'text': 'Ms. Swift won an award for best artist at the Grammy Awards.', 'entity': nan}
# {'text': 'Taylor S announced a world tour during Paris.', 'entity': nan}
# {'text': 'Ms. Swift performed a sold-out concert in Los Angeles.', 'entity': nan}
# {'text': 'TayTay revealed behind-the-scenes footage from her latest album.', 'entity': nan}
# {'text': 'TayTay engaged with fans during a live session on the Eras Tour.', 'entity': nan}
# {'text': 'Taylor announced a world tour during Los Angeles.', 'entity': nan}
# {'text': 'TayTay released a new single titled Netflix.', 'entity': nan}
# {'text': 'Swift revealed behind-the-scenes footage from Spotify.', 'entity': nan}
# {'text': 'Taylor revealed behind-the-scenes footage from Netflix.', 'entity': nan}
# {'text': 'Taylor Swift revealed behind-the-scenes footage from Paris.', 'entity': nan}
# {'text': 'T Swift revealed behind-the-scenes footage from an exclusive interview.', 'entity': nan}
# {'text': 'TayTay engaged with fans during a live session on Spotify.', 'entity': nan}
# {'text': 'Swift was featured in a documentary about Paris.', 'entity': nan}
# {'text': 'Taylor revealed behind-the-scenes footage from New York.', 'entity': nan}
# {'text': 'Swift was featured in a documentary about Los Angeles.', 'entity': nan}
# {'text': 'Taylor S spoke about her songwriting process in the Grammy Awards.', 'entity': nan}
# {'text': 'Taylor Swift performed a sold-out concert in the Grammy Awards.', 'entity': nan}
# {'text': 'Taylor spoke about her songwriting process in Spotify.', 'entity': nan}
# {'text': 'T Swift revealed behind-the-scenes footage from Los Angeles.', 'entity': nan}
# {'text': 'Ms. Swift engaged with fans during a live session on the Eras Tour.', 'entity': nan}
# {'text': 'T Swift spoke about her songwriting process in Paris.', 'entity': nan}
# {'text': 'Taylor S collaborated with another artist in a fan meet-up.', 'entity': nan}
# {'text': 'Ms. Swift spoke about her songwriting process in Paris.', 'entity': nan}
# {'text': 'TayTay was featured in a documentary about Spotify.', 'entity': nan}
# {'text': 'Taylor S won an award for best artist at the Grammy Awards.', 'entity': nan}
# {'text': 'Taylor S revealed behind-the-scenes footage from Los Angeles.', 'entity': nan}
# {'text': 'Taylor S collaborated with another artist in New York.', 'entity': nan}
# {'text': 'Taylor performed a sold-out concert in Los Angeles.', 'entity': nan}
# {'text': 'Taylor Swift spoke about her songwriting process in a fan meet-up.', 'entity': nan}
# {'text': 'Swift was featured in a documentary about a fan meet-up.', 'entity': nan}
# {'text': 'Taylor S spoke about her songwriting process in Los Angeles.', 'entity': nan}
# {'text': 'Taylor spoke about her songwriting process in New York.', 'entity': nan}
# {'text': 'TayTay appeared on a late-night show to promote her latest album.', 'entity': nan}
# {'text': 'T Swift released a new single titled New York.', 'entity': nan}
# {'text': 'T Swift appeared on a late-night show to promote the Eras Tour.', 'entity': nan}
# {'text': 'Taylor Swift was featured in a documentary about a fan meet-up.', 'entity': nan}
# {'text': 'Swift collaborated with another artist in Netflix.', 'entity': nan}
# {'text': 'Taylor spoke about her songwriting process in the Grammy Awards.', 'entity': nan}
# {'text': 'Taylor performed a sold-out concert in the Grammy Awards.', 'entity': nan}
# {'text': 'Swift appeared on a late-night show to promote her latest album.', 'entity': nan}
# {'text': 'Swift engaged with fans during a live session on New York.', 'entity': nan}
# {'text': 'Ms. Swift appeared on a late-night show to promote her latest album.', 'entity': nan}
# {'text': 'Ms. Swift performed a sold-out concert in Paris.', 'entity': nan}
# {'text': 'Taylor Swift announced a world tour during an exclusive interview.', 'entity': nan}
# {'text': 'Taylor was featured in a documentary about Los Angeles.', 'entity': nan}
# {'text': 'Taylor Swift released a new single titled a fan meet-up.', 'entity': nan}
# {'text': 'TayTay won an award for best artist at Los Angeles.', 'entity': nan}
# {'text': 'Swift revealed behind-the-scenes footage from a fan meet-up.', 'entity': nan}
# {'text': 'Taylor S spoke about her songwriting process in the Eras Tour.', 'entity': nan}
# {'text': 'T Swift collaborated with another artist in the Eras Tour.', 'entity': nan}
# {'text': 'T Swift was featured in a documentary about Paris.', 'entity': nan}
# {'text': 'Taylor revealed behind-the-scenes footage from the Grammy Awards.', 'entity': nan}
# {'text': 'T Swift revealed behind-the-scenes footage from her latest album.', 'entity': nan}
# {'text': 'Taylor announced a world tour during Spotify.', 'entity': nan}
# {'text': 'TayTay collaborated with another artist in Paris.', 'entity': nan}
# {'text': 'Taylor revealed behind-the-scenes footage from the Grammy Awards.', 'entity': nan}
# {'text': 'Taylor was featured in a documentary about an exclusive interview.', 'entity': nan}
# {'text': 'Taylor S was featured in a documentary about the Eras Tour.', 'entity': nan}
# {'text': 'Ms. Swift collaborated with another artist in Spotify.', 'entity': nan}
# {'text': 'TayTay spoke about her songwriting process in the Eras Tour.', 'entity': nan}
# {'text': 'Ms. Swift announced a world tour during her latest album.', 'entity': nan}
# {'text': 'Taylor Swift released a new single titled Paris.', 'entity': nan}
# {'text': 'Taylor Swift collaborated with another artist in Spotify.', 'entity': nan}
# {'text': 'Taylor S collaborated with another artist in Spotify.', 'entity': nan}
# {'text': 'Taylor Swift appeared on a late-night show to promote New York.', 'entity': nan}
# {'text': 'Swift collaborated with another artist in the Grammy Awards.', 'entity': nan}
# {'text': 'Taylor revealed behind-the-scenes footage from her latest album.', 'entity': nan}
# {'text': 'Swift announced a world tour during the Eras Tour.', 'entity': nan}
# {'text': 'Taylor was featured in a documentary about the Eras Tour.', 'entity': nan}
# {'text': 'Taylor Swift collaborated with another artist in New York.', 'entity': nan}
# {'text': 'Swift released a new single titled an exclusive interview.', 'entity': nan}
# {'text': 'Swift won an award for best artist at New York.', 'entity': nan}
# {'text': 'T Swift appeared on a late-night show to promote the Eras Tour.', 'entity': nan}
# {'text': 'Ms. Swift spoke about her songwriting process in her latest album.', 'entity': nan}
# {'text': 'Taylor Swift performed a sold-out concert in New York.', 'entity': nan}
# {'text': 'T Swift announced a world tour during Netflix.', 'entity': nan}
# {'text': 'Taylor performed a sold-out concert in the Eras Tour.', 'entity': nan}
# {'text': 'Taylor engaged with fans during a live session on the Eras Tour.', 'entity': nan}
# {'text': 'Ms. Swift was featured in a documentary about her latest album.', 'entity': nan}
# {'text': 'Taylor Swift appeared on a late-night show to promote Netflix.', 'entity': nan}
# {'text': 'TayTay released a new single titled a fan meet-up.', 'entity': nan}
# {'text': 'Taylor performed a sold-out concert in Netflix.', 'entity': nan}
# {'text': 'Swift released a new single titled New York.', 'entity': nan}
# {'text': 'Swift appeared on a late-night show to promote a fan meet-up.', 'entity': nan}
# {'text': 'Swift spoke about her songwriting process in Paris.', 'entity': nan}
# {'text': 'Ms. Swift announced a world tour during Los Angeles.', 'entity': nan}
# {'text': 'Taylor S won an award for best artist at New York.', 'entity': nan}
# {'text': 'Taylor released a new single titled Los Angeles.', 'entity': nan}
# {'text': 'Taylor S was featured in a documentary about an exclusive interview.', 'entity': nan}
# {'text': 'TayTay engaged with fans during a live session on an exclusive interview.', 'entity': nan}
# {'text': 'TayTay appeared on a late-night show to promote Paris.', 'entity': nan}
# {'text': 'Taylor Swift won an award for best artist at an exclusive interview.', 'entity': nan}
# {'text': 'Taylor S revealed behind-the-scenes footage from Paris.', 'entity': nan}
# {'text': 'T Swift announced a world tour during the Grammy Awards.', 'entity': nan}
# {'text': 'Taylor Swift performed a sold-out concert in the Grammy Awards.', 'entity': nan}
# {'text': 'Ms. Swift announced a world tour during a fan meet-up.', 'entity': nan}
# {'text': 'Taylor S appeared on a late-night show to promote Paris.', 'entity': nan}
# {'text': 'T Swift won an award for best artist at Paris.', 'entity': nan}
# {'text': 'Taylor announced a world tour during New York.', 'entity': nan}
# {'text': 'Taylor S engaged with fans during a live session on her latest album.', 'entity': nan}
# {'text': 'Taylor Swift announced a world tour during her latest album.', 'entity': nan}
# {'text': 'Taylor appeared on a late-night show to promote the Eras Tour.', 'entity': nan}
# {'text': 'TayTay revealed behind-the-scenes footage from Spotify.', 'entity': nan}
# {'text': 'TayTay released a new single titled her latest album.', 'entity': nan}
# {'text': 'Taylor Swift engaged with fans during a live session on Los Angeles.', 'entity': nan}
# {'text': 'Swift appeared on a late-night show to promote her latest album.', 'entity': nan}
# {'text': 'Swift appeared on a late-night show to promote Netflix.', 'entity': nan}
# {'text': 'T Swift released a new single titled New York.', 'entity': nan}
# {'text': 'Taylor S performed a sold-out concert in a fan meet-up.', 'entity': nan}
# {'text': 'TayTay appeared on a late-night show to promote Paris.', 'entity': nan}
# {'text': 'Ms. Swift engaged with fans during a live session on an exclusive interview.', 'entity': nan}
# {'text': 'Swift performed a sold-out concert in Netflix.', 'entity': nan}
# {'text': 'Swift performed a sold-out concert in Los Angeles.', 'entity': nan}
# {'text': 'T Swift announced a world tour during the Eras Tour.', 'entity': nan}
# {'text': 'T Swift appeared on a late-night show to promote the Grammy Awards.', 'entity': nan}
# {'text': 'TayTay released a new single titled a fan meet-up.', 'entity': nan}
# {'text': 'Ms. Swift appeared on a late-night show to promote New York.', 'entity': nan}
# {'text': 'Taylor appeared on a late-night show to promote Netflix.', 'entity': nan}
# {'text': 'Taylor Swift was featured in a documentary about Paris.', 'entity': nan}
# {'text': 'Swift engaged with fans during a live session on her latest album.', 'entity': nan}
# {'text': 'Taylor Swift performed a sold-out concert in Paris.', 'entity': nan}
# {'text': 'Ms. Swift performed a sold-out concert in a fan meet-up.', 'entity': nan}
# {'text': 'T Swift revealed behind-the-scenes footage from the Eras Tour.', 'entity': nan}
# {'text': 'Ms. Swift engaged with fans during a live session on Paris.', 'entity': nan}
# {'text': 'TayTay won an award for best artist at New York.', 'entity': nan}
# {'text': 'Taylor Swift spoke about her songwriting process in Netflix.', 'entity': nan}
# {'text': 'Taylor S announced a world tour during an exclusive interview.', 'entity': nan}
# {'text': 'Swift announced a world tour during Spotify.', 'entity': nan}
# {'text': 'Taylor was featured in a documentary about an exclusive interview.', 'entity': nan}
# {'text': 'T Swift performed a sold-out concert in a fan meet-up.', 'entity': nan}
# {'text': 'Taylor Swift revealed behind-the-scenes footage from Spotify.', 'entity': nan}
# {'text': 'T Swift announced a world tour during New York.', 'entity': nan}
# {'text': 'TayTay spoke about her songwriting process in Paris.', 'entity': nan}
# {'text': 'Ms. Swift was featured in a documentary about Spotify.', 'entity': nan}
# {'text': 'Taylor won an award for best artist at an exclusive interview.', 'entity': nan}
# {'text': 'TayTay announced a world tour during her latest album.', 'entity': nan}
# {'text': 'Taylor S revealed behind-the-scenes footage from Paris.', 'entity': nan}
# {'text': 'Taylor Swift announced a world tour during an exclusive interview.', 'entity': nan}
# {'text': 'Taylor Swift revealed behind-the-scenes footage from Spotify.', 'entity': nan}
# {'text': 'Swift was featured in a documentary about a fan meet-up.', 'entity': nan}
# {'text': 'Swift won an award for best artist at a fan meet-up.', 'entity': nan}
# {'text': 'Ms. Swift revealed behind-the-scenes footage from Los Angeles.', 'entity': nan}
# {'text': 'T Swift performed a sold-out concert in Netflix.', 'entity': nan}
# {'text': 'Taylor S spoke about her songwriting process in Spotify.', 'entity': nan}
# {'text': 'Taylor released a new single titled Netflix.', 'entity': nan}
# {'text': 'T Swift was featured in a documentary about New York.', 'entity': nan}
# {'text': 'T Swift collaborated with another artist in Netflix.', 'entity': nan}
# {'text': 'T Swift announced a world tour during an exclusive interview.', 'entity': nan}
# {'text': 'Taylor Swift released a new single titled Paris.', 'entity': nan}
# {'text': 'T Swift won an award for best artist at Spotify.', 'entity': nan}
# {'text': 'Taylor Swift released a new single titled Spotify.', 'entity': nan}
# {'text': 'Taylor collaborated with another artist in Paris.', 'entity': nan}
# {'text': 'Taylor won an award for best artist at an exclusive interview.', 'entity': nan}
# {'text': 'Ms. Swift was featured in a documentary about the Grammy Awards.', 'entity': nan}
# {'text': 'TayTay won an award for best artist at Los Angeles.', 'entity': nan}
# {'text': 'Taylor was featured in a documentary about a fan meet-up.', 'entity': nan}
# {'text': 'TayTay won an award for best artist at Netflix.', 'entity': nan}
# {'text': 'TayTay performed a sold-out concert in an exclusive interview.', 'entity': nan}
# {'text': 'Ms. Swift released a new single titled a fan meet-up.', 'entity': nan}
# {'text': 'Swift released a new single titled Netflix.', 'entity': nan}
# {'text': 'Swift revealed behind-the-scenes footage from the Eras Tour.', 'entity': nan}

# %% [markdown]
# Text Splitter

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=20)
chunks = text_splitter.split_documents(document)

# %% [markdown]
# Embedding and store in FAISS

# %%
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS

# %%
embed_model = HuggingFaceEmbeddings(model_name='sentence-transformers/all-mpnet-base-v2')  # Use a valid model identifier
vector_db = FAISS.from_documents(chunks, embed_model)

# %% [markdown]
# Create Retrieval

# %%
from langchain.chains import RetrievalQA
from langchain.chat_models import ChatOllama

# %%
retriever = vector_db.as_retriever()
llm = ChatOllama(model="llama3")

# %%
qa = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type='stuff',
    retriever=retriever,
    return_source_documents=True
)

# %%
query = "What is the name of the person who played football in Green Bay?"
print(qa(query)['result'])
# Out:
# Based on the provided context, it seems that Aaron Rodgers is the Green Bay QB who was featured in various sports segments and was traded to a new team during NFL Honors.

# %%
query = "Who is coducting illict trafficking of weaposns?"
print(qa(query)['result'])
# Out:
# Based on the given context, it appears that Black Market Liaison and Shadow Broker are both involved in illicit trafficking of weapons. Specifically:
#
# * Black Market Liaison used a front company to ship cargo through the Tri-Border Area, suggesting they may be conducting arms trafficking.
# * Shadow Broker was connected to arms trafficking routes near a remote airstrip in Sudan.
#
# It seems that both Black Market Liaison and Shadow Broker are involved in illegal weapon trading activities.

# %%
query = "Jane Doe has released multiple surprise albums during the pandemic, often writing and producing them herself. She avoids public political statements but once criticized a senator. Can you tell me who she might actually be?"
print(qa(query)['result'])
# Out:
# Based on the context provided, it's possible that Jane Doe is actually Taylor Swift. Taylor Swift was featured in a documentary about Spotify, which matches one of the given pieces of context. Additionally, Taylor Swift has released surprise albums during the pandemic and has been known to write and produce her own music. She also tends to avoid public political statements but has occasionally spoken out against certain politicians or policies.

# %%
query = "Does this database have Steve Jobs?"
print(qa(query)['result'])
# Out:
# Yes, based on the provided context, it appears that Steve Jobs is mentioned several times as being featured or appearing on covers related to Apple events and products, such as Macworld, iPhone launch, WWDC, and Apple Event.

# %%
query = "Based on similar activities, focus on job: Jane Doe has released multiple surprise albums during the pandemic, often writing and producing them herself. She avoids public political statements but once criticized a senator. Can you tell me who she might actually be?"
print(qa(query)['result'])
# Out:
# A fun challenge!
#
# Given Jane Doe's activities of releasing surprise albums, writing and producing them herself, and avoiding public political statements with one notable exception (criticizing a senator), I can try to make an educated guess.
#
# Considering the context provided earlier, it seems that some celebrities have been involved in cybersecurity-related incidents or have taken stands on certain issues. With Jane Doe's behavior mirroring Taylor Swift's in terms of surprise album releases and self-production, I'm going to take a wild guess and say that Jane Doe might actually be Taylor Swift!

# %% [markdown]
# Going to add a political spectrum; to simulate from dicatorship to dictatorship resistance
